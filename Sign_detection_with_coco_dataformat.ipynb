# %% [markdown]
# <a href="https://colab.research.google.com/github/sachinv899/assignment/blob/main/Sign_detection_with_coco_dataformat.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Microcontroller Instance Segmentation with COCO dataformat
# <img src="https://dl.fbaipublicfiles.com/detectron2/Detectron2-Logo-Horz.png" width="500">

# %% [markdown]
# <table align="left"><td>
#   <a target="_blank"  href="https://colab.research.google.com/github/TannerGilbert/Detectron2-Train-a-Instance-Segmentation-Model/blob/master/Microcontroller_Instance_Segmentation_with_COCO_dataformat.ipynb">
#     <img src="https://www.tensorflow.org/images/colab_logo_32px.png" />Run in Google Colab
#   </a>
# </td><td>
#   <a target="_blank"  href="https://github.com/TannerGilbert/Detectron2-Train-a-Instance-Segmentation-Model/blob/master/Microcontroller_Instance_Segmentation_with_COCO_dataformat.ipynb">
#     <img width=32px src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
# </td></table>

# %% [markdown]
# ## Install detectron2
#
# > **Important**: If you're running on a local machine, be sure to follow the [installation instructions](https://github.com/facebookresearch/detectron2/blob/master/INSTALL.md). This notebook includes only what's necessary to run in Colab.

# %%
# !python -m pip install pyyaml==5.1
# Detectron2 has not released pre-built binaries for the latest pytorch (https://github.com/facebookresearch/detectron2/issues/4053)
# so we install from source instead. This takes a few minutes.
# !python -m pip install 'git+https://github.com/facebookresearch/detectron2.git'

# Install pre-built detectron2 that matches pytorch version, if released:
# See https://detectron2.readthedocs.io/tutorials/install.html for instructions
#!pip install detectron2 -f https://dl.fbaipublicfiles.com/detectron2/wheels/{CUDA_VERSION}/{TORCH_VERSION}/index.html

# exit(0)  # After installation, you may need to "restart runtime" in Colab. This line can also restart runtime
import torch, detectron2
# !nvcc --version
TORCH_VERSION = ".".join(torch.__version__.split(".")[:2])
CUDA_VERSION = torch.__version__.split("+")[-1]
print("torch: ", TORCH_VERSION, "; cuda: ", CUDA_VERSION)
print("detectron2:", detectron2.__version__)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pyyaml==5.1
#   Downloading PyYAML-5.1.tar.gz (274 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 274.2/274.2 kB 13.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: pyyaml
#   Building wheel for pyyaml (setup.py) ... done
#   Created wheel for pyyaml: filename=PyYAML-5.1-cp310-cp310-linux_x86_64.whl size=44090 sha256=9e648cf8db73672c8b4861fc0bbcccb51450fb8e6bef7c6323e18a916d783053
#   Stored in directory: /root/.cache/pip/wheels/70/83/31/975b737609aba39a4099d471d5684141c1fdc3404f97e7f68a
# Successfully built pyyaml
# Installing collected packages: pyyaml
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 6.0
#     Uninstalling PyYAML-6.0:
#       Successfully uninstalled PyYAML-6.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dask 2022.12.1 requires pyyaml>=5.3.1, but you have pyyaml 5.1 which is incompatible.
# flax 0.6.9 requires PyYAML>=5.4.1, but you have pyyaml 5.1 which is incompatible.
# Successfully installed pyyaml-5.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting git+https://github.com/facebookresearch/detectron2.git
#   Cloning https://github.com/facebookresearch/detectron2.git to /tmp/pip-req-build-lofju1kd
#   Running command git clone --filter=blob:none --quiet https://github.com/facebookresearch/detectron2.git /tmp/pip-req-build-lofju1kd
#   Resolved https://github.com/facebookresearch/detectron2.git to commit 2c6c380f94a27bd8455a39506c9105f652b9f760
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: Pillow>=7.1 in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (8.4.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (3.7.1)
# Requirement already satisfied: pycocotools>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (2.0.6)
# Requirement already satisfied: termcolor>=1.1 in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (2.3.0)
# Collecting yacs>=0.1.8 (from detectron2==0.6)
#   Downloading yacs-0.1.8-py3-none-any.whl (14 kB)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (0.8.10)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (2.2.1)
# Requirement already satisfied: tqdm>4.29.0 in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (4.65.0)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (2.12.2)
# Collecting fvcore<0.1.6,>=0.1.5 (from detectron2==0.6)
#   Downloading fvcore-0.1.5.post20221221.tar.gz (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 4.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting iopath<0.1.10,>=0.1.7 (from detectron2==0.6)
#   Downloading iopath-0.1.9-py3-none-any.whl (27 kB)
# Collecting omegaconf>=2.1 (from detectron2==0.6)
#   Downloading omegaconf-2.3.0-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 10.8 MB/s eta 0:00:00
# Collecting hydra-core>=1.1 (from detectron2==0.6)
#   Downloading hydra_core-1.3.2-py3-none-any.whl (154 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 18.6 MB/s eta 0:00:00
# Collecting black (from detectron2==0.6)
#   Downloading black-23.3.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 75.4 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (23.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from fvcore<0.1.6,>=0.1.5->detectron2==0.6) (1.22.4)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from fvcore<0.1.6,>=0.1.5->detectron2==0.6) (5.1)
# Collecting antlr4-python3-runtime==4.9.* (from hydra-core>=1.1->detectron2==0.6)
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 16.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting portalocker (from iopath<0.1.10,>=0.1.7->detectron2==0.6)
#   Downloading portalocker-2.7.0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2==0.6) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2==0.6) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2==0.6) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2==0.6) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2==0.6) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2==0.6) (2.8.2)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from black->detectron2==0.6) (8.1.3)
# Collecting mypy-extensions>=0.4.3 (from black->detectron2==0.6)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Collecting pathspec>=0.9.0 (from black->detectron2==0.6)
#   Downloading pathspec-0.11.1-py3-none-any.whl (29 kB)
# Requirement already satisfied: platformdirs>=2 in /usr/local/lib/python3.10/dist-packages (from black->detectron2==0.6) (3.3.0)
# Requirement already satisfied: tomli>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from black->detectron2==0.6) (2.0.1)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (1.54.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (3.4.3)
# Requirement already satisfied: protobuf>=3.19.6 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (2.27.1)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (67.7.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (0.7.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (2.3.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (0.40.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2==0.6) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2==0.6) (0.3.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2==0.6) (1.16.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2==0.6) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard->detectron2==0.6) (1.3.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard->detectron2==0.6) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard->detectron2==0.6) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard->detectron2==0.6) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard->detectron2==0.6) (3.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard->detectron2==0.6) (2.1.2)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->detectron2==0.6) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard->detectron2==0.6) (3.2.2)
# Building wheels for collected packages: detectron2, fvcore, antlr4-python3-runtime
#   Building wheel for detectron2 (setup.py) ... done
#   Created wheel for detectron2: filename=detectron2-0.6-cp310-cp310-linux_x86_64.whl size=7802619 sha256=40b35ae0471109cdea7c694156ca82359abc765ad3d582ac1469fd8d162a5e7e
#   Stored in directory: /tmp/pip-ephem-wheel-cache-1nixn3pd/wheels/47/e5/15/94c80df2ba85500c5d76599cc307c0a7079d0e221bb6fc4375
#   Building wheel for fvcore (setup.py) ... done
#   Created wheel for fvcore: filename=fvcore-0.1.5.post20221221-py3-none-any.whl size=61405 sha256=b813570030d41b233e9fa7b692d05f9cf8c3e4a724df231999e5d76d33210072
#   Stored in directory: /root/.cache/pip/wheels/01/c0/af/77c1cf53a1be9e42a52b48e5af2169d40ec2e89f7362489dd0
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144554 sha256=afb39bb683ef60f24520da11f8594b39d1b440ef93c09c9813ab5af5133ede67
#   Stored in directory: /root/.cache/pip/wheels/12/93/dd/1f6a127edc45659556564c5730f6d4e300888f4bca2d4c5a88
# Successfully built detectron2 fvcore antlr4-python3-runtime
# Installing collected packages: antlr4-python3-runtime, yacs, portalocker, pathspec, omegaconf, mypy-extensions, iopath, hydra-core, black, fvcore, detectron2
# Successfully installed antlr4-python3-runtime-4.9.3 black-23.3.0 detectron2-0.6 fvcore-0.1.5.post20221221 hydra-core-1.3.2 iopath-0.1.9 mypy-extensions-1.0.0 omegaconf-2.3.0 pathspec-0.11.1 portalocker-2.7.0 yacs-0.1.8
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2022 NVIDIA Corporation
# Built on Wed_Sep_21_10:33:58_PDT_2022
# Cuda compilation tools, release 11.8, V11.8.89
# Build cuda_11.8.r11.8/compiler.31833905_0
# torch:  2.0 ; cuda:  cu118
# detectron2: 0.6

# %%
# !pip install pyyaml==5.1

import torch
TORCH_VERSION = ".".join(torch.__version__.split(".")[:2])
CUDA_VERSION = torch.__version__.split("+")[-1]
print("torch: ", TORCH_VERSION, "; cuda: ", CUDA_VERSION)
# Install detectron2 that matches the above pytorch version
# See https://detectron2.readthedocs.io/tutorials/install.html for instructions
# !pip install detectron2 -f https://dl.fbaipublicfiles.com/detectron2/wheels/$CUDA_VERSION/torch$TORCH_VERSION/index.html
# If there is not yet a detectron2 release that matches the given torch + CUDA version, you need to install a different pytorch.

# exit(0)  # After installation, you may need to "restart runtime" in Colab. This line can also restart runtime
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pyyaml==5.1 in /usr/local/lib/python3.10/dist-packages (5.1)
# torch:  2.0 ; cuda:  cu118
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Looking in links: https://dl.fbaipublicfiles.com/detectron2/wheels/cu118/torch2.0/index.html
# Requirement already satisfied: detectron2 in /usr/local/lib/python3.10/dist-packages (0.6)
# Requirement already satisfied: Pillow>=7.1 in /usr/local/lib/python3.10/dist-packages (from detectron2) (8.4.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from detectron2) (3.7.1)
# Requirement already satisfied: pycocotools>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from detectron2) (2.0.6)
# Requirement already satisfied: termcolor>=1.1 in /usr/local/lib/python3.10/dist-packages (from detectron2) (2.3.0)
# Requirement already satisfied: yacs>=0.1.8 in /usr/local/lib/python3.10/dist-packages (from detectron2) (0.1.8)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from detectron2) (0.8.10)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from detectron2) (2.2.1)
# Requirement already satisfied: tqdm>4.29.0 in /usr/local/lib/python3.10/dist-packages (from detectron2) (4.65.0)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.10/dist-packages (from detectron2) (2.12.2)
# Requirement already satisfied: fvcore<0.1.6,>=0.1.5 in /usr/local/lib/python3.10/dist-packages (from detectron2) (0.1.5.post20221221)
# Requirement already satisfied: iopath<0.1.10,>=0.1.7 in /usr/local/lib/python3.10/dist-packages (from detectron2) (0.1.9)
# Requirement already satisfied: omegaconf>=2.1 in /usr/local/lib/python3.10/dist-packages (from detectron2) (2.3.0)
# Requirement already satisfied: hydra-core>=1.1 in /usr/local/lib/python3.10/dist-packages (from detectron2) (1.3.2)
# Requirement already satisfied: black in /usr/local/lib/python3.10/dist-packages (from detectron2) (23.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from detectron2) (23.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from fvcore<0.1.6,>=0.1.5->detectron2) (1.22.4)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from fvcore<0.1.6,>=0.1.5->detectron2) (5.1)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.10/dist-packages (from hydra-core>=1.1->detectron2) (4.9.3)
# Requirement already satisfied: portalocker in /usr/local/lib/python3.10/dist-packages (from iopath<0.1.10,>=0.1.7->detectron2) (2.7.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2) (2.8.2)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from black->detectron2) (8.1.3)
# Requirement already satisfied: mypy-extensions>=0.4.3 in /usr/local/lib/python3.10/dist-packages (from black->detectron2) (1.0.0)
# Requirement already satisfied: pathspec>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from black->detectron2) (0.11.1)
# Requirement already satisfied: platformdirs>=2 in /usr/local/lib/python3.10/dist-packages (from black->detectron2) (3.3.0)
# Requirement already satisfied: tomli>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from black->detectron2) (2.0.1)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2) (1.54.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2) (3.4.3)
# Requirement already satisfied: protobuf>=3.19.6 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2) (2.27.1)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2) (67.7.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2) (0.7.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2) (2.3.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2) (0.40.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2) (0.3.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2) (1.16.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard->detectron2) (1.3.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard->detectron2) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard->detectron2) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard->detectron2) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard->detectron2) (3.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard->detectron2) (2.1.2)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->detectron2) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard->detectron2) (3.2.2)

# %%
import torch, detectron2
# !nvcc --version
TORCH_VERSION = ".".join(torch.__version__.split(".")[:2])
CUDA_VERSION = torch.__version__.split("+")[-1]
print("torch: ", TORCH_VERSION, "; cuda: ", CUDA_VERSION)
print("detectron2:", detectron2.__version__)
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2022 NVIDIA Corporation
# Built on Wed_Sep_21_10:33:58_PDT_2022
# Cuda compilation tools, release 11.8, V11.8.89
# Build cuda_11.8.r11.8/compiler.31833905_0
# torch:  2.0 ; cuda:  cu118
# detectron2: 0.6

# %% [markdown]
# ## Get data

# %%
import detectron2
from detectron2.utils.logger import setup_logger
setup_logger()

# import some common libraries
import numpy as np
import cv2
import matplotlib.pyplot as plt

# import some common detectron2 utilities
from detectron2 import model_zoo
from detectron2.engine import DefaultPredictor
from detectron2.config import get_cfg
from detectron2.utils.visualizer import Visualizer
from detectron2.data import MetadataCatalog, DatasetCatalog

# %%
# !wget https://raw.githubusercontent.com/Priyeshprajapati/test12/main/microcontroller_segmentation_data.zip
# !unzip microcontroller_segmentation_data.zip
# !ls
# Out:
# --2023-05-23 10:49:05--  https://raw.githubusercontent.com/Priyeshprajapati/test12/main/microcontroller_segmentation_data.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 12332306 (12M) [application/zip]
# Saving to: ‘microcontroller_segmentation_data.zip’
#
# microcontroller_seg 100%[===================>]  11.76M  --.-KB/s    in 0.07s
#
# 2023-05-23 10:49:06 (164 MB/s) - ‘microcontroller_segmentation_data.zip’ saved [12332306/12332306]
#
# Archive:  microcontroller_segmentation_data.zip
#   inflating: Microcontroller Segmentation/test.json
#    creating: Microcontroller Segmentation/test/
#   inflating: Microcontroller Segmentation/test/033902b97317e31f23bae7452eda3364.json
#   inflating: Microcontroller Segmentation/test/033902b97317e31f23bae7452eda3364.png
#   inflating: Microcontroller Segmentation/test/1280px-Jon_Kirsch27s_Signature.json
#   inflating: Microcontroller Segmentation/test/1280px-Jon_Kirsch27s_Signature.png
#   inflating: Microcontroller Segmentation/test/1280px-Zhu_Zhengting_signature.jpg
#   inflating: Microcontroller Segmentation/test/1280px-Zhu_Zhengting_signature.json
#   inflating: Microcontroller Segmentation/test/20190126_175250.jpg
#   inflating: Microcontroller Segmentation/test/20190126_175250.json
#   inflating: Microcontroller Segmentation/test/image.jpeg
#   inflating: Microcontroller Segmentation/test/image.json
#   inflating: Microcontroller Segmentation/test/image2.jpeg
#   inflating: Microcontroller Segmentation/test/image2.json
#   inflating: Microcontroller Segmentation/test/image3.jpeg
#   inflating: Microcontroller Segmentation/test/image3.json
#   inflating: Microcontroller Segmentation/test/image6.jpeg
#   inflating: Microcontroller Segmentation/test/image6.json
#   inflating: Microcontroller Segmentation/test/image7.jpeg
#   inflating: Microcontroller Segmentation/test/image7.json
#   inflating: Microcontroller Segmentation/test/image8.jpeg
#   inflating: Microcontroller Segmentation/test/image8.json
#   inflating: Microcontroller Segmentation/train.json
#    creating: Microcontroller Segmentation/train/
#   inflating: Microcontroller Segmentation/train/033902b97317e31f23bae7452eda3364.json
#   inflating: Microcontroller Segmentation/train/033902b97317e31f23bae7452eda3364.png
#   inflating: Microcontroller Segmentation/train/1200px-Signature_of_the_HRH_Meghan2C_Duchess_of_Sussex.svg.json
#   inflating: Microcontroller Segmentation/train/1200px-Signature_of_the_HRH_Meghan2C_Duchess_of_Sussex.svg.png
#   inflating: Microcontroller Segmentation/train/1280px-Jon_Kirsch27s_Signature.json
#   inflating: Microcontroller Segmentation/train/1280px-Jon_Kirsch27s_Signature.png
#   inflating: Microcontroller Segmentation/train/1280px-Zhu_Zhengting_signature.jpg
#   inflating: Microcontroller Segmentation/train/1280px-Zhu_Zhengting_signature.json
#   inflating: Microcontroller Segmentation/train/20190126_175250.jpg
#   inflating: Microcontroller Segmentation/train/20190126_175250.json
#   inflating: Microcontroller Segmentation/train/332-3322416_fake-signature-png-transparent-png.json
#   inflating: Microcontroller Segmentation/train/332-3322416_fake-signature-png-transparent-png.png
#   inflating: Microcontroller Segmentation/train/360_F_429547_YJTlwk2Ld5kYDAbtCUwFgzmatgUHEg.jpg
#   inflating: Microcontroller Segmentation/train/360_F_429547_YJTlwk2Ld5kYDAbtCUwFgzmatgUHEg.json
#   inflating: Microcontroller Segmentation/train/416-4164278_transparent-michael-jordan-signature-png-autograph-png-png.json
#   inflating: Microcontroller Segmentation/train/416-4164278_transparent-michael-jordan-signature-png-autograph-png-png.png
#   inflating: Microcontroller Segmentation/train/518-5183368_graphic-free-library-transparent-signature-random-random-signature.json
#   inflating: Microcontroller Segmentation/train/518-5183368_graphic-free-library-transparent-signature-random-random-signature.png
#   inflating: Microcontroller Segmentation/train/518-5183699_clip-freeuse-download-signatures-for-free-fancy-signature.json
#   inflating: Microcontroller Segmentation/train/518-5183699_clip-freeuse-download-signatures-for-free-fancy-signature.png
#   inflating: Microcontroller Segmentation/train/57526075-pen-writing-the-word-signature-on-a-white-piece-of-paper.jpg
#   inflating: Microcontroller Segmentation/train/57526075-pen-writing-the-word-signature-on-a-white-piece-of-paper.json
#   inflating: Microcontroller Segmentation/train/59fc6ee45b4e2_thumb900.jpg
#   inflating: Microcontroller Segmentation/train/59fc6ee45b4e2_thumb900.json
#   inflating: Microcontroller Segmentation/train/6a14a2565834045849ddda1eba92f92c.jpg
#   inflating: Microcontroller Segmentation/train/6a14a2565834045849ddda1eba92f92c.json
#   inflating: Microcontroller Segmentation/train/88c9231057e5501cd08e032c8f289575.jpg
#   inflating: Microcontroller Segmentation/train/88c9231057e5501cd08e032c8f289575.json
#   inflating: Microcontroller Segmentation/train/c15f2e6613bcc1d72ad367f6215b4a1e.json
#   inflating: Microcontroller Segmentation/train/c15f2e6613bcc1d72ad367f6215b4a1e.png
#   inflating: Microcontroller Segmentation/train/D._Harlan_Wilson_28signature29.jpg
#   inflating: Microcontroller Segmentation/train/D._Harlan_Wilson_28signature29.json
#   inflating: Microcontroller Segmentation/train/draw-a-beautiful-handwritten-signature-on-paper.jpg
#   inflating: Microcontroller Segmentation/train/draw-a-beautiful-handwritten-signature-on-paper.json
#   inflating: Microcontroller Segmentation/train/esign1.json
#   inflating: Microcontroller Segmentation/train/esign1.png
#   inflating: Microcontroller Segmentation/train/f20ac40f866a74daaaf8058ed1192832.jpg
#   inflating: Microcontroller Segmentation/train/f20ac40f866a74daaaf8058ed1192832.json
#   inflating: Microcontroller Segmentation/train/fiancee-of-Britains-Prince-William-Kate-Middleton-is-seen-in-the-book-of-con.jpg
#   inflating: Microcontroller Segmentation/train/fiancee-of-Britains-Prince-William-Kate-Middleton-is-seen-in-the-book-of-con.json
#   inflating: Microcontroller Segmentation/train/free-db385-signature-36dfb-generator-392ea-easily-16cb5-sign-fb1d8-digital-0f431-docs.json
#   inflating: Microcontroller Segmentation/train/free-db385-signature-36dfb-generator-392ea-easily-16cb5-sign-fb1d8-digital-0f431-docs.png
#   inflating: Microcontroller Segmentation/train/FRZTZZQHVFL7IKN (2).jpg
#   inflating: Microcontroller Segmentation/train/FRZTZZQHVFL7IKN (2).json
#   inflating: Microcontroller Segmentation/train/FRZTZZQHVFL7IKN.jpg
#   inflating: Microcontroller Segmentation/train/FRZTZZQHVFL7IKN.json
#   inflating: Microcontroller Segmentation/train/handwritten-signature-example (2).json
#   inflating: Microcontroller Segmentation/train/handwritten-signature-example (2).png
#   inflating: Microcontroller Segmentation/train/handwritten-signature-example.json
#   inflating: Microcontroller Segmentation/train/handwritten-signature-example.png
#   inflating: Microcontroller Segmentation/train/how-to-create-and-insert-signatures-in-Microsoft-Word-step-1_4d470f76dc99e18ad75087b1b8410ea9.jpg
#   inflating: Microcontroller Segmentation/train/how-to-create-and-insert-signatures-in-Microsoft-Word-step-1_4d470f76dc99e18ad75087b1b8410ea9.json
#   inflating: Microcontroller Segmentation/train/image (2).jpeg
#   inflating: Microcontroller Segmentation/train/image (2).json
#   inflating: Microcontroller Segmentation/train/image.jpeg
#   inflating: Microcontroller Segmentation/train/image.json
#   inflating: Microcontroller Segmentation/train/image_2321 (2).json
#   inflating: Microcontroller Segmentation/train/image_2321 (2).png
#   inflating: Microcontroller Segmentation/train/image_2321.json
#   inflating: Microcontroller Segmentation/train/image_2321.png
#   inflating: Microcontroller Segmentation/train/image17.json
#   inflating: Microcontroller Segmentation/train/image17.png
#   inflating: Microcontroller Segmentation/train/image18.json
#   inflating: Microcontroller Segmentation/train/image18.png
#   inflating: Microcontroller Segmentation/train/image19.json
#  extracting: Microcontroller Segmentation/train/image19.png
#   inflating: Microcontroller Segmentation/train/image2 (2).jpeg
#   inflating: Microcontroller Segmentation/train/image2 (2).json
#   inflating: Microcontroller Segmentation/train/image2.jpeg
#   inflating: Microcontroller Segmentation/train/image2.json
#   inflating: Microcontroller Segmentation/train/image20.json
#  extracting: Microcontroller Segmentation/train/image20.png
#   inflating: Microcontroller Segmentation/train/image3.jpeg
#   inflating: Microcontroller Segmentation/train/image3.json
#   inflating: Microcontroller Segmentation/train/image4 (2).jpeg
#   inflating: Microcontroller Segmentation/train/image4 (2).json
#   inflating: Microcontroller Segmentation/train/image4 (3).jpeg
#   inflating: Microcontroller Segmentation/train/image4 (3).json
#   inflating: Microcontroller Segmentation/train/image4.jpeg
#   inflating: Microcontroller Segmentation/train/image4.json
#   inflating: Microcontroller Segmentation/train/image5 (2).jpeg
#   inflating: Microcontroller Segmentation/train/image5 (2).json
#   inflating: Microcontroller Segmentation/train/image5 (3).jpeg
#   inflating: Microcontroller Segmentation/train/image5 (3).json
#   inflating: Microcontroller Segmentation/train/image5.jpeg
#   inflating: Microcontroller Segmentation/train/image5.json
#   inflating: Microcontroller Segmentation/train/image6 (2).jpeg
#   inflating: Microcontroller Segmentation/train/image6 (2).json
#   inflating: Microcontroller Segmentation/train/image6.jpeg
#   inflating: Microcontroller Segmentation/train/image6.json
#   inflating: Microcontroller Segmentation/train/image7 (2).jpeg
#   inflating: Microcontroller Segmentation/train/image7 (2).json
#   inflating: Microcontroller Segmentation/train/image7.jpeg
#   inflating: Microcontroller Segmentation/train/image7.json
#   inflating: Microcontroller Segmentation/train/image8.jpeg
#   inflating: Microcontroller Segmentation/train/image8.json
#   inflating: Microcontroller Segmentation/train/image9.jpeg
#   inflating: Microcontroller Segmentation/train/image9.json
#   inflating: Microcontroller Segmentation/train/image-file-format-f.jpg
#   inflating: Microcontroller Segmentation/train/image-file-format-f.json
#   inflating: Microcontroller Segmentation/train/images42.jpg
#   inflating: Microcontroller Segmentation/train/images42.json
#   inflating: Microcontroller Segmentation/train/images45.jpg
#   inflating: Microcontroller Segmentation/train/images45.json
#   inflating: Microcontroller Segmentation/train/images49.jpg
#   inflating: Microcontroller Segmentation/train/images49.json
#   inflating: Microcontroller Segmentation/train/images52.jpg
#   inflating: Microcontroller Segmentation/train/images52.json
#   inflating: Microcontroller Segmentation/train/images53.jpg
#   inflating: Microcontroller Segmentation/train/images53.json
#   inflating: Microcontroller Segmentation/train/signature (1).jpg
#   inflating: Microcontroller Segmentation/train/signature (1).json
#   inflating: Microcontroller Segmentation/train/signature (10).jpg
#   inflating: Microcontroller Segmentation/train/signature (10).json
#   inflating: Microcontroller Segmentation/train/signature (11).jpg
#   inflating: Microcontroller Segmentation/train/signature (11).json
#   inflating: Microcontroller Segmentation/train/signature (12).jpg
#   inflating: Microcontroller Segmentation/train/signature (12).json
#   inflating: Microcontroller Segmentation/train/signature (13).jpg
#   inflating: Microcontroller Segmentation/train/signature (13).json
#   inflating: Microcontroller Segmentation/train/signature (14).jpg
#   inflating: Microcontroller Segmentation/train/signature (14).json
#   inflating: Microcontroller Segmentation/train/signature (15).jpg
#   inflating: Microcontroller Segmentation/train/signature (15).json
#   inflating: Microcontroller Segmentation/train/signature (16).jpg
#   inflating: Microcontroller Segmentation/train/signature (16).json
#   inflating: Microcontroller Segmentation/train/signature (17).jpg
#   inflating: Microcontroller Segmentation/train/signature (17).json
#   inflating: Microcontroller Segmentation/train/signature (18).jpg
#   inflating: Microcontroller Segmentation/train/signature (18).json
#   inflating: Microcontroller Segmentation/train/signature (19).jpg
#   inflating: Microcontroller Segmentation/train/signature (19).json
#   inflating: Microcontroller Segmentation/train/signature (2).jpg
#   inflating: Microcontroller Segmentation/train/signature (2).json
#   inflating: Microcontroller Segmentation/train/signature (20).jpg
#   inflating: Microcontroller Segmentation/train/signature (20).json
#   inflating: Microcontroller Segmentation/train/signature (21).jpg
#   inflating: Microcontroller Segmentation/train/signature (21).json
#   inflating: Microcontroller Segmentation/train/signature (22).jpg
#   inflating: Microcontroller Segmentation/train/signature (22).json
#   inflating: Microcontroller Segmentation/train/signature (23).jpg
#   inflating: Microcontroller Segmentation/train/signature (23).json
#   inflating: Microcontroller Segmentation/train/signature (24).jpg
#   inflating: Microcontroller Segmentation/train/signature (24).json
#   inflating: Microcontroller Segmentation/train/signature (25).jpg
#   inflating: Microcontroller Segmentation/train/signature (25).json
#   inflating: Microcontroller Segmentation/train/signature (3).jpg
#   inflating: Microcontroller Segmentation/train/signature (3).json
#   inflating: Microcontroller Segmentation/train/signature (4).jpg
#   inflating: Microcontroller Segmentation/train/signature (5).jpg
#   inflating: Microcontroller Segmentation/train/signature (5).json
#   inflating: Microcontroller Segmentation/train/signature (6).jpg
#   inflating: Microcontroller Segmentation/train/signature (6).json
#   inflating: Microcontroller Segmentation/train/signature (7).jpg
#   inflating: Microcontroller Segmentation/train/signature (7).json
#   inflating: Microcontroller Segmentation/train/signature (8).jpg
#   inflating: Microcontroller Segmentation/train/signature (8).json
#   inflating: Microcontroller Segmentation/train/signature (9).jpg
#   inflating: Microcontroller Segmentation/train/signature (9).json
#   inflating: Microcontroller Segmentation/train/signature.jpg
#   inflating: Microcontroller Segmentation/train/signaturelight_2x.json
#   inflating: Microcontroller Segmentation/train/signaturelight_2x.png
#   inflating: Microcontroller Segmentation/train/signature-on-a-sheet-of-paper-illustration_csp35365629.jpg
#   inflating: Microcontroller Segmentation/train/signature-on-a-sheet-of-paper-illustration_csp35365629.json
#   inflating: Microcontroller Segmentation/train/signature-on-a-sheet-of-paper-KJ8Y80 (2).jpg
#   inflating: Microcontroller Segmentation/train/signature-on-a-sheet-of-paper-KJ8Y80 (2).json
#   inflating: Microcontroller Segmentation/train/signature-on-a-sheet-of-paper-KJ8Y80.jpg
#   inflating: Microcontroller Segmentation/train/signature-on-a-sheet-of-paper-KJ8Y80.json
#   inflating: Microcontroller Segmentation/train/signature-on-image.jpg
#   inflating: Microcontroller Segmentation/train/signature-on-image.json
#   inflating: Microcontroller Segmentation/train/underline-signature-mean-personality.jpg
#   inflating: Microcontroller Segmentation/train/underline-signature-mean-personality.json
#   inflating: Microcontroller Segmentation/train/vector-signature-autograph-hand-drawn-260nw-2046349127.jpg
#   inflating: Microcontroller Segmentation/train/vector-signature-autograph-hand-drawn-260nw-2046349127.json
#  download.png
#  manual-signature-documents-on-white-260nw-1389794327.webp
# 'Microcontroller Segmentation'
#  microcontroller_segmentation_data.zip
#  NapoleonSignature2_1050x700.webp
#  pexels-mike-bird-3729464.jpg
#  sample_data

# %%
# !ls 'Microcontroller Segmentation'
# Out:
# test  test.json  train	train.json

# %% [markdown]
# ## Register data-set
#
# In order to use a dataset with Detectron2 we need to register it. For more information check out the official documentation.

# %%
from detectron2.data.datasets import register_coco_instances

for d in ["train", "test"]:
    register_coco_instances(f"microcontroller_{d}", {}, f"Microcontroller Segmentation/{d}.json", f"Microcontroller Segmentation/{d}")

# %%
import random
from detectron2.data import DatasetCatalog, MetadataCatalog

dataset_dicts = DatasetCatalog.get("microcontroller_train")
microcontroller_metadata = MetadataCatalog.get("microcontroller_train")

for d in random.sample(dataset_dicts, 3):
    img = cv2.imread(d["file_name"])
    v = Visualizer(img[:, :, ::-1], metadata=microcontroller_metadata, scale=0.5)
    v = v.draw_dataset_dict(d)
    plt.figure(figsize = (14, 10))
    plt.imshow(cv2.cvtColor(v.get_image()[:, :, ::-1], cv2.COLOR_BGR2RGB))
    plt.show()
# Out:
# WARNING [05/23 10:49:07 d2.data.datasets.coco]:
# Category ids in annotations are not in [1, #categories]! We'll apply a mapping for you.
#
# [05/23 10:49:07 d2.data.datasets.coco]: Loaded 86 images in COCO format from Microcontroller Segmentation/train.json

# %%
#test*******************************

# %%
from detectron2.data import detection_utils as utils
import detectron2.data.transforms as T
import copy
import torch

def custom_mapper(dataset_dict):
    dataset_dicts = copy.deepcopy(dataset_dict)  # it will be modified by code below
    image = utils.read_image(dataset_dict["file_name"], format="BGR")
    transform_list = [
        T.Resize((800,600)),
        T.RandomBrightness(0.8, 1.8),
        T.RandomContrast(0.6, 1.3),
        T.RandomSaturation(0.8, 1.4),
        T.RandomRotation(angle=[90, 90]),
        T.RandomLighting(0.7),
        T.RandomFlip(prob=0.4, horizontal=False, vertical=True),
    ]
    image, transforms = T.apply_transform_gens(transform_list, image)
    dataset_dict["image"] = torch.as_tensor(image.transpose(2, 0, 1).astype("float32"))

    annos = [
        utils.transform_instance_annotations(obj, transforms, image.shape[:2])
        for obj in dataset_dict.pop("annotations")
        if obj.get("iscrowd", 0) == 0
    ]
    instances = utils.annotations_to_instances(annos, image.shape[:2])
    dataset_dict["instances"] = utils.filter_empty_instances(instances)
    return dataset_dicts

# %%
from detectron2.engine import DefaultTrainer
from detectron2.data import build_detection_test_loader, build_detection_train_loader

class CustomTrainer(DefaultTrainer):
    @classmethod
    def build_train_loader(cls, cfg):
        return build_detection_train_loader(cfg, mapper=custom_mapper)

# %% [markdown]
# ## Train model
#
# Now, let's fine-tune a pretrained FasterRCNN instance segmentation model on the microcontroller data-set.

# %%
from detectron2.engine import DefaultTrainer
from detectron2.config import get_cfg
import os

cfg = get_cfg()
cfg.merge_from_file(model_zoo.get_config_file("COCO-Detection/faster_rcnn_R_50_FPN_3x.yaml"))
cfg.DATASETS.TRAIN = ("microcontroller_train",)
cfg.DATASETS.TEST = ()
cfg.DATALOADER.NUM_WORKERS = 2
cfg.MODEL.WEIGHTS = model_zoo.get_checkpoint_url("COCO-Detection/faster_rcnn_R_50_FPN_3x.yaml")
cfg.SOLVER.IMS_PER_BATCH = 2
cfg.SOLVER.BASE_LR = 0.00025
cfg.SOLVER.MAX_ITER = 1000
cfg.SOLVER.STEPS = []        # do not decay learning rate
cfg.MODEL.ROI_HEADS.NUM_CLASSES = 4

os.makedirs(cfg.OUTPUT_DIR, exist_ok=True)
trainer = DefaultTrainer(cfg) 
trainer.resume_or_load(resume=False)
trainer.train()


# from detectron2.config import get_cfg

# cfg = get_cfg()
# cfg.merge_from_file(model_zoo.get_config_file("COCO-Detection/faster_rcnn_R_101_FPN_3x.yaml"))
# cfg.DATASETS.TRAIN = ("microcontroller_train",)
# cfg.DATASETS.TEST = ()   # no metrics implemented for this dataset
# cfg.DATALOADER.NUM_WORKERS = 2
# cfg.MODEL.WEIGHTS = model_zoo.get_checkpoint_url("COCO-Detection/faster_rcnn_R_101_FPN_3x.yaml")  # initialize from model zoo
# cfg.SOLVER.IMS_PER_BATCH = 2
# cfg.SOLVER.BASE_LR = 0.00025
# cfg.SOLVER.MAX_ITER = 500
# cfg.SOLVER.STEPS = []        # do not decay learning rate
# cfg.MODEL.ROI_HEADS.BATCH_SIZE_PER_IMAGE = 128   # faster, and good enough for this toy dataset
# cfg.MODEL.ROI_HEADS.NUM_CLASSES = 1  # only has one class (ballon)

# os.makedirs(cfg.OUTPUT_DIR, exist_ok=True)
# trainer = CustomTrainer(cfg) 
# trainer.resume_or_load(resume=False)
# trainer.train()
# Out:
# [05/23 10:49:09 d2.engine.defaults]: Model:
# GeneralizedRCNN(
#   (backbone): FPN(
#     (fpn_lateral2): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral3): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral4): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral5): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (top_block): LastLevelMaxPool()
#     (bottom_up): ResNet(
#       (stem): BasicStem(
#         (conv1): Conv2d(
#           3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#         )
#       )
#       (res2): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#       )
#       (res3): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             256, 128, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#       )
#       (res4): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             512, 256, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (4): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (5): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#       )
#       (res5): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             1024, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#       )
#     )
#   )
#   (proposal_generator): RPN(
#     (rpn_head): StandardRPNHead(
#       (conv): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (objectness_logits): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#       (anchor_deltas): Conv2d(256, 12, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (anchor_generator): DefaultAnchorGenerator(
#       (cell_anchors): BufferList()
#     )
#   )
#   (roi_heads): StandardROIHeads(
#     (box_pooler): ROIPooler(
#       (level_poolers): ModuleList(
#         (0): ROIAlign(output_size=(7, 7), spatial_scale=0.25, sampling_ratio=0, aligned=True)
#         (1): ROIAlign(output_size=(7, 7), spatial_scale=0.125, sampling_ratio=0, aligned=True)
#         (2): ROIAlign(output_size=(7, 7), spatial_scale=0.0625, sampling_ratio=0, aligned=True)
#         (3): ROIAlign(output_size=(7, 7), spatial_scale=0.03125, sampling_ratio=0, aligned=True)
#       )
#     )
#     (box_head): FastRCNNConvFCHead(
#       (flatten): Flatten(start_dim=1, end_dim=-1)
#       (fc1): Linear(in_features=12544, out_features=1024, bias=True)
#       (fc_relu1): ReLU()
#       (fc2): Linear(in_features=1024, out_features=1024, bias=True)
#       (fc_relu2): ReLU()
#     )
#     (box_predictor): FastRCNNOutputLayers(
#       (cls_score): Linear(in_features=1024, out_features=5, bias=True)
#       (bbox_pred): Linear(in_features=1024, out_features=16, bias=True)
#     )
#   )
# )
# WARNING [05/23 10:49:09 d2.data.datasets.coco]:
# Category ids in annotations are not in [1, #categories]! We'll apply a mapping for you.
#
# [05/23 10:49:09 d2.data.datasets.coco]: Loaded 86 images in COCO format from Microcontroller Segmentation/train.json
# [05/23 10:49:09 d2.data.build]: Removed 0 images with no usable annotations. 86 images left.
# [05/23 10:49:09 d2.data.build]: Distribution of instances among all 1 categories:
# |  category  | #instances   |
# |:----------:|:-------------|
# |    sign    | 86           |
# |            |              |
# [05/23 10:49:09 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [ResizeShortestEdge(short_edge_length=(640, 672, 704, 736, 768, 800), max_size=1333, sample_style='choice'), RandomFlip()]
# [05/23 10:49:09 d2.data.build]: Using training sampler TrainingSampler
# [05/23 10:49:09 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [05/23 10:49:09 d2.data.common]: Serializing 86 elements to byte tensors and concatenating them all ...
# [05/23 10:49:09 d2.data.common]: Serialized dataset takes 0.03 MiB
# [05/23 10:49:09 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from https://dl.fbaipublicfiles.com/detectron2/COCO-Detection/faster_rcnn_R_50_FPN_3x/137849458/model_final_280758.pkl ...
# model_final_280758.pkl: 167MB [00:00, 177MB/s]
# WARNING:fvcore.common.checkpoint:Skip loading parameter 'roi_heads.box_predictor.cls_score.weight' to the model due to incompatible shapes: (81, 1024) in the checkpoint but (5, 1024) in the model! You might want to double check if this is expected.
# WARNING:fvcore.common.checkpoint:Skip loading parameter 'roi_heads.box_predictor.cls_score.bias' to the model due to incompatible shapes: (81,) in the checkpoint but (5,) in the model! You might want to double check if this is expected.
# WARNING:fvcore.common.checkpoint:Skip loading parameter 'roi_heads.box_predictor.bbox_pred.weight' to the model due to incompatible shapes: (320, 1024) in the checkpoint but (16, 1024) in the model! You might want to double check if this is expected.
# WARNING:fvcore.common.checkpoint:Skip loading parameter 'roi_heads.box_predictor.bbox_pred.bias' to the model due to incompatible shapes: (320,) in the checkpoint but (16,) in the model! You might want to double check if this is expected.
# WARNING:fvcore.common.checkpoint:Some model parameters or buffers are not found in the checkpoint:
# roi_heads.box_predictor.bbox_pred.{bias, weight}
# roi_heads.box_predictor.cls_score.{bias, weight}
# [05/23 10:49:11 d2.engine.train_loop]: Starting training from iteration 0
# /usr/local/lib/python3.10/dist-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3483.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# [05/23 10:49:23 d2.utils.events]:  eta: 0:07:06  iter: 19  total_loss: 1.651  loss_cls: 1.515  loss_box_reg: 0.1005  loss_rpn_cls: 0.00931  loss_rpn_loc: 0.01227    time: 0.4287  last_time: 0.3783  data_time: 0.0259  last_data_time: 0.0053   lr: 4.9953e-06  max_mem: 2544M
# [05/23 10:49:42 d2.utils.events]:  eta: 0:07:58  iter: 39  total_loss: 1.422  loss_cls: 1.321  loss_box_reg: 0.1014  loss_rpn_cls: 0.01189  loss_rpn_loc: 0.01408    time: 0.5182  last_time: 0.5058  data_time: 0.0438  last_data_time: 0.0154   lr: 9.9902e-06  max_mem: 2641M
# [05/23 10:49:51 d2.utils.events]:  eta: 0:07:20  iter: 59  total_loss: 1.071  loss_cls: 0.9267  loss_box_reg: 0.1128  loss_rpn_cls: 0.004654  loss_rpn_loc: 0.0153    time: 0.4917  last_time: 0.5098  data_time: 0.0120  last_data_time: 0.0148   lr: 1.4985e-05  max_mem: 2641M
# [05/23 10:50:00 d2.utils.events]:  eta: 0:06:59  iter: 79  total_loss: 0.6675  loss_cls: 0.5583  loss_box_reg: 0.08046  loss_rpn_cls: 0.005212  loss_rpn_loc: 0.01249    time: 0.4777  last_time: 0.3836  data_time: 0.0131  last_data_time: 0.0117   lr: 1.998e-05  max_mem: 2641M
# [05/23 10:50:09 d2.utils.events]:  eta: 0:06:54  iter: 99  total_loss: 0.448  loss_cls: 0.314  loss_box_reg: 0.1009  loss_rpn_cls: 0.006343  loss_rpn_loc: 0.01369    time: 0.4788  last_time: 0.3923  data_time: 0.0392  last_data_time: 0.0133   lr: 2.4975e-05  max_mem: 2641M
# [05/23 10:50:18 d2.utils.events]:  eta: 0:06:42  iter: 119  total_loss: 0.3552  loss_cls: 0.2082  loss_box_reg: 0.1084  loss_rpn_cls: 0.01009  loss_rpn_loc: 0.01529    time: 0.4742  last_time: 0.5803  data_time: 0.0131  last_data_time: 0.0568   lr: 2.997e-05  max_mem: 2641M
# [05/23 10:50:28 d2.utils.events]:  eta: 0:06:34  iter: 139  total_loss: 0.2878  loss_cls: 0.1534  loss_box_reg: 0.09754  loss_rpn_cls: 0.006898  loss_rpn_loc: 0.01285    time: 0.4724  last_time: 0.4355  data_time: 0.0111  last_data_time: 0.0115   lr: 3.4965e-05  max_mem: 2641M
# [05/23 10:50:37 d2.utils.events]:  eta: 0:06:26  iter: 159  total_loss: 0.2558  loss_cls: 0.136  loss_box_reg: 0.09557  loss_rpn_cls: 0.004075  loss_rpn_loc: 0.01377    time: 0.4717  last_time: 0.4166  data_time: 0.0209  last_data_time: 0.0138   lr: 3.996e-05  max_mem: 2641M
# [05/23 10:50:46 d2.utils.events]:  eta: 0:06:19  iter: 179  total_loss: 0.2559  loss_cls: 0.1152  loss_box_reg: 0.09451  loss_rpn_cls: 0.004289  loss_rpn_loc: 0.01669    time: 0.4719  last_time: 0.4546  data_time: 0.0096  last_data_time: 0.0010   lr: 4.4955e-05  max_mem: 2641M
# [05/23 10:50:56 d2.utils.events]:  eta: 0:06:15  iter: 199  total_loss: 0.2507  loss_cls: 0.1216  loss_box_reg: 0.09632  loss_rpn_cls: 0.006985  loss_rpn_loc: 0.01233    time: 0.4733  last_time: 0.5558  data_time: 0.0124  last_data_time: 0.0072   lr: 4.995e-05  max_mem: 2641M
# [05/23 10:51:06 d2.utils.events]:  eta: 0:06:09  iter: 219  total_loss: 0.2428  loss_cls: 0.1263  loss_box_reg: 0.1056  loss_rpn_cls: 0.002093  loss_rpn_loc: 0.01347    time: 0.4769  last_time: 0.7522  data_time: 0.0125  last_data_time: 0.0074   lr: 5.4945e-05  max_mem: 2641M
# [05/23 10:51:16 d2.utils.events]:  eta: 0:06:00  iter: 239  total_loss: 0.2413  loss_cls: 0.1111  loss_box_reg: 0.1029  loss_rpn_cls: 0.002713  loss_rpn_loc: 0.01483    time: 0.4786  last_time: 0.4851  data_time: 0.0148  last_data_time: 0.0220   lr: 5.994e-05  max_mem: 2641M
# [05/23 10:51:26 d2.utils.events]:  eta: 0:05:50  iter: 259  total_loss: 0.2371  loss_cls: 0.1117  loss_box_reg: 0.09387  loss_rpn_cls: 0.005561  loss_rpn_loc: 0.0116    time: 0.4800  last_time: 0.4893  data_time: 0.0131  last_data_time: 0.0067   lr: 6.4935e-05  max_mem: 2641M
# [05/23 10:51:37 d2.utils.events]:  eta: 0:05:41  iter: 279  total_loss: 0.2028  loss_cls: 0.08578  loss_box_reg: 0.07437  loss_rpn_cls: 0.001141  loss_rpn_loc: 0.01462    time: 0.4826  last_time: 1.0272  data_time: 0.0375  last_data_time: 0.5334   lr: 6.993e-05  max_mem: 2641M
# [05/23 10:51:46 d2.utils.events]:  eta: 0:05:33  iter: 299  total_loss: 0.235  loss_cls: 0.1089  loss_box_reg: 0.1146  loss_rpn_cls: 0.003026  loss_rpn_loc: 0.01016    time: 0.4827  last_time: 0.4447  data_time: 0.0113  last_data_time: 0.0186   lr: 7.4925e-05  max_mem: 2643M
# [05/23 10:51:56 d2.utils.events]:  eta: 0:05:24  iter: 319  total_loss: 0.2097  loss_cls: 0.09423  loss_box_reg: 0.1001  loss_rpn_cls: 0.003002  loss_rpn_loc: 0.0134    time: 0.4839  last_time: 0.4595  data_time: 0.0184  last_data_time: 0.0050   lr: 7.992e-05  max_mem: 2643M
# [05/23 10:52:06 d2.utils.events]:  eta: 0:05:17  iter: 339  total_loss: 0.2328  loss_cls: 0.09599  loss_box_reg: 0.1092  loss_rpn_cls: 0.002239  loss_rpn_loc: 0.01315    time: 0.4846  last_time: 0.5892  data_time: 0.0123  last_data_time: 0.0102   lr: 8.4915e-05  max_mem: 2643M
# [05/23 10:52:16 d2.utils.events]:  eta: 0:05:07  iter: 359  total_loss: 0.2057  loss_cls: 0.08346  loss_box_reg: 0.1043  loss_rpn_cls: 0.0009392  loss_rpn_loc: 0.009079    time: 0.4848  last_time: 0.6895  data_time: 0.0296  last_data_time: 0.2884   lr: 8.991e-05  max_mem: 2643M
# [05/23 10:52:26 d2.utils.events]:  eta: 0:04:58  iter: 379  total_loss: 0.2133  loss_cls: 0.07723  loss_box_reg: 0.09469  loss_rpn_cls: 0.003613  loss_rpn_loc: 0.01543    time: 0.4857  last_time: 0.5496  data_time: 0.0104  last_data_time: 0.0211   lr: 9.4905e-05  max_mem: 2643M
# [05/23 10:52:36 d2.utils.events]:  eta: 0:04:48  iter: 399  total_loss: 0.2054  loss_cls: 0.08497  loss_box_reg: 0.1075  loss_rpn_cls: 0.002189  loss_rpn_loc: 0.01018    time: 0.4860  last_time: 0.4342  data_time: 0.0181  last_data_time: 0.0175   lr: 9.99e-05  max_mem: 2643M
# [05/23 10:52:46 d2.utils.events]:  eta: 0:04:38  iter: 419  total_loss: 0.193  loss_cls: 0.07201  loss_box_reg: 0.1006  loss_rpn_cls: 0.002709  loss_rpn_loc: 0.01044    time: 0.4859  last_time: 0.4812  data_time: 0.0149  last_data_time: 0.0276   lr: 0.0001049  max_mem: 2643M
# [05/23 10:52:56 d2.utils.events]:  eta: 0:04:31  iter: 439  total_loss: 0.192  loss_cls: 0.07297  loss_box_reg: 0.1001  loss_rpn_cls: 0.001027  loss_rpn_loc: 0.01081    time: 0.4883  last_time: 0.5004  data_time: 0.0306  last_data_time: 0.0200   lr: 0.00010989  max_mem: 2643M
# [05/23 10:53:06 d2.utils.events]:  eta: 0:04:21  iter: 459  total_loss: 0.1893  loss_cls: 0.07253  loss_box_reg: 0.1021  loss_rpn_cls: 0.001154  loss_rpn_loc: 0.01263    time: 0.4878  last_time: 0.5011  data_time: 0.0114  last_data_time: 0.0055   lr: 0.00011489  max_mem: 2643M
# [05/23 10:53:16 d2.utils.events]:  eta: 0:04:12  iter: 479  total_loss: 0.1817  loss_cls: 0.06732  loss_box_reg: 0.09528  loss_rpn_cls: 0.00186  loss_rpn_loc: 0.01303    time: 0.4885  last_time: 0.4689  data_time: 0.0154  last_data_time: 0.0039   lr: 0.00011988  max_mem: 2643M
# [05/23 10:53:26 d2.utils.events]:  eta: 0:04:02  iter: 499  total_loss: 0.1979  loss_cls: 0.06289  loss_box_reg: 0.09857  loss_rpn_cls: 0.001005  loss_rpn_loc: 0.01053    time: 0.4887  last_time: 0.5480  data_time: 0.0125  last_data_time: 0.0053   lr: 0.00012488  max_mem: 2643M
# [05/23 10:53:36 d2.utils.events]:  eta: 0:03:53  iter: 519  total_loss: 0.1887  loss_cls: 0.05818  loss_box_reg: 0.1105  loss_rpn_cls: 0.001093  loss_rpn_loc: 0.009169    time: 0.4895  last_time: 0.5083  data_time: 0.0230  last_data_time: 0.0178   lr: 0.00012987  max_mem: 2643M
# [05/23 10:53:46 d2.utils.events]:  eta: 0:03:43  iter: 539  total_loss: 0.1707  loss_cls: 0.0553  loss_box_reg: 0.09455  loss_rpn_cls: 0.0006731  loss_rpn_loc: 0.01002    time: 0.4900  last_time: 0.5038  data_time: 0.0242  last_data_time: 0.0184   lr: 0.00013487  max_mem: 2643M
# [05/23 10:53:56 d2.utils.events]:  eta: 0:03:33  iter: 559  total_loss: 0.1865  loss_cls: 0.06461  loss_box_reg: 0.1076  loss_rpn_cls: 0.002035  loss_rpn_loc: 0.01117    time: 0.4900  last_time: 0.4529  data_time: 0.0116  last_data_time: 0.0085   lr: 0.00013986  max_mem: 2643M
# [05/23 10:54:06 d2.utils.events]:  eta: 0:03:24  iter: 579  total_loss: 0.1879  loss_cls: 0.05575  loss_box_reg: 0.1138  loss_rpn_cls: 0.0006708  loss_rpn_loc: 0.00759    time: 0.4899  last_time: 0.3947  data_time: 0.0119  last_data_time: 0.0031   lr: 0.00014486  max_mem: 2643M
# [05/23 10:54:16 d2.utils.events]:  eta: 0:03:15  iter: 599  total_loss: 0.1694  loss_cls: 0.05351  loss_box_reg: 0.09173  loss_rpn_cls: 0.0006766  loss_rpn_loc: 0.01044    time: 0.4898  last_time: 0.4101  data_time: 0.0152  last_data_time: 0.0077   lr: 0.00014985  max_mem: 2643M
# [05/23 10:54:26 d2.utils.events]:  eta: 0:03:05  iter: 619  total_loss: 0.1733  loss_cls: 0.05713  loss_box_reg: 0.1084  loss_rpn_cls: 0.0005861  loss_rpn_loc: 0.01051    time: 0.4903  last_time: 0.4489  data_time: 0.0122  last_data_time: 0.0260   lr: 0.00015485  max_mem: 2643M
# [05/23 10:54:35 d2.utils.events]:  eta: 0:02:55  iter: 639  total_loss: 0.184  loss_cls: 0.05295  loss_box_reg: 0.1165  loss_rpn_cls: 0.0009759  loss_rpn_loc: 0.006946    time: 0.4898  last_time: 0.5038  data_time: 0.0121  last_data_time: 0.0106   lr: 0.00015984  max_mem: 2643M
# [05/23 10:54:45 d2.utils.events]:  eta: 0:02:46  iter: 659  total_loss: 0.1715  loss_cls: 0.05315  loss_box_reg: 0.1022  loss_rpn_cls: 0.0005346  loss_rpn_loc: 0.009667    time: 0.4899  last_time: 0.5721  data_time: 0.0137  last_data_time: 0.0179   lr: 0.00016484  max_mem: 2643M
# [05/23 10:54:55 d2.utils.events]:  eta: 0:02:36  iter: 679  total_loss: 0.1716  loss_cls: 0.05023  loss_box_reg: 0.08825  loss_rpn_cls: 0.0009203  loss_rpn_loc: 0.009965    time: 0.4907  last_time: 0.5176  data_time: 0.0337  last_data_time: 0.0068   lr: 0.00016983  max_mem: 2643M
# [05/23 10:55:06 d2.utils.events]:  eta: 0:02:26  iter: 699  total_loss: 0.171  loss_cls: 0.04411  loss_box_reg: 0.106  loss_rpn_cls: 0.0004192  loss_rpn_loc: 0.009235    time: 0.4913  last_time: 0.4330  data_time: 0.0327  last_data_time: 0.0051   lr: 0.00017483  max_mem: 2643M
# [05/23 10:55:15 d2.utils.events]:  eta: 0:02:16  iter: 719  total_loss: 0.154  loss_cls: 0.04468  loss_box_reg: 0.1004  loss_rpn_cls: 0.001119  loss_rpn_loc: 0.007223    time: 0.4906  last_time: 0.4964  data_time: 0.0109  last_data_time: 0.0187   lr: 0.00017982  max_mem: 2643M
# [05/23 10:55:25 d2.utils.events]:  eta: 0:02:06  iter: 739  total_loss: 0.1518  loss_cls: 0.04528  loss_box_reg: 0.1045  loss_rpn_cls: 0.001204  loss_rpn_loc: 0.009793    time: 0.4903  last_time: 0.5145  data_time: 0.0160  last_data_time: 0.0099   lr: 0.00018482  max_mem: 2643M
# [05/23 10:55:35 d2.utils.events]:  eta: 0:01:57  iter: 759  total_loss: 0.1535  loss_cls: 0.04662  loss_box_reg: 0.09598  loss_rpn_cls: 0.0007961  loss_rpn_loc: 0.008243    time: 0.4907  last_time: 0.5233  data_time: 0.0129  last_data_time: 0.0207   lr: 0.00018981  max_mem: 2643M
# [05/23 10:55:45 d2.utils.events]:  eta: 0:01:47  iter: 779  total_loss: 0.14  loss_cls: 0.04161  loss_box_reg: 0.06823  loss_rpn_cls: 0.0003814  loss_rpn_loc: 0.01428    time: 0.4917  last_time: 0.5616  data_time: 0.0531  last_data_time: 0.0158   lr: 0.00019481  max_mem: 2643M
# [05/23 10:55:55 d2.utils.events]:  eta: 0:01:38  iter: 799  total_loss: 0.1434  loss_cls: 0.04469  loss_box_reg: 0.09265  loss_rpn_cls: 0.0003851  loss_rpn_loc: 0.007233    time: 0.4914  last_time: 0.4545  data_time: 0.0130  last_data_time: 0.0276   lr: 0.0001998  max_mem: 2643M
# [05/23 10:56:05 d2.utils.events]:  eta: 0:01:28  iter: 819  total_loss: 0.1301  loss_cls: 0.04203  loss_box_reg: 0.07814  loss_rpn_cls: 0.0001234  loss_rpn_loc: 0.008529    time: 0.4914  last_time: 0.4570  data_time: 0.0138  last_data_time: 0.0061   lr: 0.0002048  max_mem: 2643M
# [05/23 10:56:14 d2.utils.events]:  eta: 0:01:18  iter: 839  total_loss: 0.1506  loss_cls: 0.04706  loss_box_reg: 0.08355  loss_rpn_cls: 0.001288  loss_rpn_loc: 0.007028    time: 0.4911  last_time: 0.4917  data_time: 0.0129  last_data_time: 0.0133   lr: 0.00020979  max_mem: 2643M
# [05/23 10:56:24 d2.utils.events]:  eta: 0:01:08  iter: 859  total_loss: 0.1226  loss_cls: 0.03711  loss_box_reg: 0.06378  loss_rpn_cls: 0.0001526  loss_rpn_loc: 0.01063    time: 0.4910  last_time: 0.3890  data_time: 0.0195  last_data_time: 0.0069   lr: 0.00021479  max_mem: 2643M
# [05/23 10:56:33 d2.utils.events]:  eta: 0:00:58  iter: 879  total_loss: 0.1397  loss_cls: 0.04549  loss_box_reg: 0.08115  loss_rpn_cls: 0.0001443  loss_rpn_loc: 0.00627    time: 0.4904  last_time: 0.5084  data_time: 0.0106  last_data_time: 0.0152   lr: 0.00021978  max_mem: 2643M
# [05/23 10:56:44 d2.utils.events]:  eta: 0:00:49  iter: 899  total_loss: 0.1243  loss_cls: 0.03945  loss_box_reg: 0.0734  loss_rpn_cls: 0.0005919  loss_rpn_loc: 0.009013    time: 0.4909  last_time: 0.4405  data_time: 0.0193  last_data_time: 0.0036   lr: 0.00022478  max_mem: 2643M
# [05/23 10:56:54 d2.utils.events]:  eta: 0:00:39  iter: 919  total_loss: 0.1164  loss_cls: 0.037  loss_box_reg: 0.0637  loss_rpn_cls: 0.0001919  loss_rpn_loc: 0.009106    time: 0.4911  last_time: 0.4461  data_time: 0.0148  last_data_time: 0.0192   lr: 0.00022977  max_mem: 2643M
# [05/23 10:57:04 d2.utils.events]:  eta: 0:00:29  iter: 939  total_loss: 0.1266  loss_cls: 0.04428  loss_box_reg: 0.06693  loss_rpn_cls: 0.0007531  loss_rpn_loc: 0.006354    time: 0.4912  last_time: 0.5028  data_time: 0.0184  last_data_time: 0.0033   lr: 0.00023477  max_mem: 2643M
# [05/23 10:57:14 d2.utils.events]:  eta: 0:00:19  iter: 959  total_loss: 0.1024  loss_cls: 0.03412  loss_box_reg: 0.05428  loss_rpn_cls: 0.0001016  loss_rpn_loc: 0.007215    time: 0.4913  last_time: 0.5189  data_time: 0.0125  last_data_time: 0.0265   lr: 0.00023976  max_mem: 2643M
# [05/23 10:57:23 d2.utils.events]:  eta: 0:00:09  iter: 979  total_loss: 0.1105  loss_cls: 0.03768  loss_box_reg: 0.05982  loss_rpn_cls: 0.0001012  loss_rpn_loc: 0.006277    time: 0.4912  last_time: 0.5085  data_time: 0.0140  last_data_time: 0.0063   lr: 0.00024476  max_mem: 2643M
# [05/23 10:57:34 d2.utils.events]:  eta: 0:00:00  iter: 999  total_loss: 0.1239  loss_cls: 0.04166  loss_box_reg: 0.05999  loss_rpn_cls: 0.0003238  loss_rpn_loc: 0.01477    time: 0.4913  last_time: 0.4133  data_time: 0.0121  last_data_time: 0.0233   lr: 0.00024975  max_mem: 2643M
# [05/23 10:57:35 d2.engine.hooks]: Overall training speed: 998 iterations in 0:08:10 (0.4913 s / it)
# [05/23 10:57:35 d2.engine.hooks]: Total training time: 0:08:19 (0:00:09 on hooks)

# %% [markdown]
# ## Use model for inference
#
# Now, we can perform inference on our validation set by creating a predictor object.

# %%
cfg.MODEL.WEIGHTS = os.path.join(cfg.OUTPUT_DIR, "model_final.pth")
cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST = 0.9 
cfg.DATASETS.TEST = ("microcontroller_test", )
predictor = DefaultPredictor(cfg)
# Out:
# [05/23 10:57:35 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from ./output/model_final.pth ...

# %%
from detectron2.utils.visualizer import ColorMode
dataset_dicts = DatasetCatalog.get("microcontroller_train")
for d in random.sample(dataset_dicts, 3):    
    im = cv2.imread(d["file_name"])
    outputs = predictor(im)
    v = Visualizer(im[:, :, ::-1],
                   metadata=microcontroller_metadata, 
                   scale=0.8, 
                   instance_mode=ColorMode.IMAGE_BW   # remove the colors of unsegmented pixels
    )
    v = v.draw_instance_predictions(outputs["instances"].to("cpu"))
    plt.figure(figsize = (14, 10))
    plt.imshow(cv2.cvtColor(v.get_image()[:, :, ::-1], cv2.COLOR_BGR2RGB))
    plt.show()
# Out:
# WARNING [05/23 11:25:52 d2.data.datasets.coco]:
# Category ids in annotations are not in [1, #categories]! We'll apply a mapping for you.
#
# [05/23 11:25:52 d2.data.datasets.coco]: Loaded 86 images in COCO format from Microcontroller Segmentation/train.json

# %%
from detectron2.evaluation import COCOEvaluator, inference_on_dataset
from detectron2.data import build_detection_test_loader
evaluator = COCOEvaluator("microcontroller_test", ("bbox",), False, output_dir="./output/")
val_loader = build_detection_test_loader(cfg, "microcontroller_test")
print(inference_on_dataset(trainer.model, val_loader, evaluator))
# another equivalent way to evaluate the model is to use `trainer.test`
# Out:
# WARNING [05/23 10:57:37 d2.data.datasets.coco]:
# Category ids in annotations are not in [1, #categories]! We'll apply a mapping for you.
#
# [05/23 10:57:37 d2.data.datasets.coco]: Loaded 10 images in COCO format from Microcontroller Segmentation/test.json
# [05/23 10:57:37 d2.data.build]: Distribution of instances among all 1 categories:
# |  category  | #instances   |
# |:----------:|:-------------|
# |    sign    | 10           |
# |            |              |
# [05/23 10:57:37 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [05/23 10:57:37 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [05/23 10:57:37 d2.data.common]: Serializing 10 elements to byte tensors and concatenating them all ...
# [05/23 10:57:37 d2.data.common]: Serialized dataset takes 0.00 MiB
# [05/23 10:57:37 d2.evaluation.evaluator]: Start inference on 10 batches
# [05/23 10:57:39 d2.evaluation.evaluator]: Total inference time: 0:00:00.607512 (0.121502 s / iter per device, on 1 devices)
# [05/23 10:57:39 d2.evaluation.evaluator]: Total inference pure compute time: 0:00:00 (0.104628 s / iter per device, on 1 devices)
# [05/23 10:57:39 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [05/23 10:57:39 d2.evaluation.coco_evaluation]: Saving results to ./output/coco_instances_results.json
# [05/23 10:57:39 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# [05/23 10:57:39 d2.evaluation.fast_eval_api]: Evaluate annotation type *bbox*
# [05/23 10:57:39 d2.evaluation.fast_eval_api]: COCOeval_opt.evaluate() finished in 0.00 seconds.
# [05/23 10:57:39 d2.evaluation.fast_eval_api]: Accumulating evaluation results...
# [05/23 10:57:39 d2.evaluation.fast_eval_api]: COCOeval_opt.accumulate() finished in 0.00 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.741
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 1.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.800
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.729
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.790
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.790
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.790
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.800
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.787
# [05/23 10:57:39 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50   |  AP75   |  APs  |  APm   |  APl   |
# |:------:|:-------:|:-------:|:-----:|:------:|:------:|
# | 74.089 | 100.000 | 100.000 |  nan  | 80.000 | 72.869 |
# [05/23 10:57:39 d2.evaluation.coco_evaluation]: Some metrics cannot be computed and is shown as NaN.
# OrderedDict([('bbox', {'AP': 74.08910891089108, 'AP50': 100.0, 'AP75': 100.0, 'APs': nan, 'APm': 80.0, 'APl': 72.86853685368536})])

# %%
# cfg = get_cfg()
# cfg.merge_from_file(model_zoo.get_config_file("COCO-Detection/faster_rcnn_R_50_FPN_3x.yaml"))
# cfg.INPUT.MASK_FORMAT='bitmask'
# cfg.MODEL.WEIGHTS = "/content/output/model_final.pth" 
# cfg.MODEL.ROI_HEADS.NUM_CLASSES = 1 
# #cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST = 0.40
# cfg.TEST.DETECTIONS_PER_IMAGE = 1000
# predictor = DefaultPredictor(cfg)
# THRESHOLDS = [.15, .35, .55]
# MIN_PIXELS = [75, 150, 75]

# %%
from google.colab.patches import cv2_imshow
image_path = "/content/download.png"
image = cv2.imread(image_path)
outputs = predictor(image)
v = Visualizer(image[:, :, ::-1], MetadataCatalog.get(cfg.DATASETS.TRAIN[0]), scale=1.2)
out = v.draw_instance_predictions(outputs["instances"].to("cpu"))
cv2_imshow(cv2.imread('/content/download.png'))
cv2_imshow(out.get_image()[:, :, ::-1])
# Out:
# <PIL.Image.Image image mode=RGB size=300x168 at 0x7F17923A0310>
# <PIL.Image.Image image mode=RGB size=360x201 at 0x7F1791DB9CC0>

# %%
from google.colab.patches import cv2_imshow
image_path = "/content/d-small-man-double-thumbs-up-image-white-background-142522587.jpg"
image = cv2.imread(image_path)
outputs = predictor(image)
v = Visualizer(image[:, :, ::-1], MetadataCatalog.get(cfg.DATASETS.TRAIN[0]), scale=1.2)
out = v.draw_instance_predictions(outputs["instances"].to("cpu"))
cv2_imshow(cv2.imread('/content/d-small-man-double-thumbs-up-image-white-background-142522587.jpg'))
cv2_imshow(out.get_image()[:, :, ::-1])
# Out:
# <PIL.Image.Image image mode=RGB size=675x900 at 0x7F1791DBAE90>
# <PIL.Image.Image image mode=RGB size=810x1080 at 0x7F1791D9A1A0>
